# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"""MobileNet v2.
MobileNet is a general architechture and can be used for multiple cases.
Depending on the use case, it can use different input layer size and differnt head
(for example: embeddings, localization and classsifcation)

As described in https://arxiv.org/abs/1801.04381.

Inversed Resisuals and Liear Bottlenecks:Mobile Networks ofr Classification, Detection and Segmentation
Mark Sandler, Andrew Howard, Menglong Zhu, Andrew Zhmoginov, Liang-chieh Chen
"""

# %%
from __future__ import absolut_import
from __future__ import division
from __future__ import print_function

from collections import namedtuple
import functools
import tensorflow as tf

slim = tf.contrib.slim

Conv = namedtuple('Conv', ['kernel', 'stride', 'depth'])
InvResBlock = namedtuple('InvResBlock', ['kernel', 'stride', 'depth', 'repeate'])

# %%
def relu(x, name='relu6'):
    return tf.nn.relu6(x, name)
# Out:
#   File "<ipython-input-8-216538ed5042>", line 4
#     def batch_norm(x, momentum=0.9, epsilon=1e-5, train=True, name='bn'):
#                                                                          ^
# SyntaxError: unexpected EOF while parsing
